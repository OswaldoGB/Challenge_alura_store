# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda1.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
facturacion_tienda1 = tienda1["Precio"].sum()
facturacion_tienda2 = tienda2["Precio"].sum()
facturacion_tienda3 = tienda3["Precio"].sum()
facturacion_tienda4 = tienda4["Precio"].sum()

print("Facturación total por tienda:\n")

print(f"Tienda 1: ${facturacion_tienda1:,.2f}")
print(f"Tienda 2: ${facturacion_tienda2:,.2f}")
print(f"Tienda 3: ${facturacion_tienda3:,.2f}")
print(f"Tienda 4: ${facturacion_tienda4:,.2f}")
# Out:
# Facturación total por tienda:
#
# Tienda 1: $1,150,880,400.00
# Tienda 2: $1,116,343,500.00
# Tienda 3: $1,098,019,600.00
# Tienda 4: $1,038,375,700.00

# %% [markdown]
# # 2. Ventas por categoría

# %%
print("="*50)
print("VENTAS POR CATEGORÍA")
print("="*50)

def ventas_por_categoria(tienda, nombre_tienda):
    
    categorias = tienda["Categoría del Producto"].value_counts()
    total_ventas = categorias.sum()
    
    print(f"\n📍 {nombre_tienda}")
    print("-"*40)
    
    for categoria, cantidad in categorias.items():
        porcentaje = (cantidad / total_ventas) * 100
        print(f"{categoria:<25} {cantidad:>8,} ventas   ({porcentaje:5.2f}%)")

ventas_por_categoria(tienda1, "Tienda 1")
ventas_por_categoria(tienda2, "Tienda 2")
ventas_por_categoria(tienda3, "Tienda 3")
ventas_por_categoria(tienda4, "Tienda 4")
# Out:
# ...
# VENTAS POR CATEGORÍA
# ...
#
# 📍 Tienda 1
# ----------------------------------------
# Muebles                        465 ventas   (19.71%)
# Electrónicos                   448 ventas   (18.99%)
# Juguetes                       324 ventas   (13.73%)
# Electrodomésticos              312 ventas   (13.23%)
# Deportes y diversión           284 ventas   (12.04%)
# Instrumentos musicales         182 ventas   ( 7.72%)
# Libros                         173 ventas   ( 7.33%)
# Artículos para el hogar        171 ventas   ( 7.25%)
#
# 📍 Tienda 2
# ----------------------------------------
# Muebles                        442 ventas   (18.74%)
# Electrónicos                   422 ventas   (17.89%)
# Juguetes                       313 ventas   (13.27%)
# Electrodomésticos              305 ventas   (12.93%)
# Deportes y diversión           275 ventas   (11.66%)
# Instrumentos musicales         224 ventas   ( 9.50%)
# Libros                         197 ventas   ( 8.35%)
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
print("Promedio de calificación de clientes:\n")

print(f"Tienda 1: {tienda1['Calificación'].mean():.2f}")
print(f"Tienda 2: {tienda2['Calificación'].mean():.2f}")
print(f"Tienda 3: {tienda3['Calificación'].mean():.2f}")
print(f"Tienda 4: {tienda4['Calificación'].mean():.2f}")
# Out:
# Promedio de calificación de clientes:
#
# Tienda 1: 3.98
# Tienda 2: 4.04
# Tienda 3: 4.05
# Tienda 4: 4.00

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
print("Productos más y menos vendidos:\n")

print("Tienda 1")
print("Más vendido:", tienda1["Producto"].value_counts().idxmax())
print("Menos vendido:", tienda1["Producto"].value_counts().idxmin())

print("\nTienda 2")
print("Más vendido:", tienda2["Producto"].value_counts().idxmax())
print("Menos vendido:", tienda2["Producto"].value_counts().idxmin())

print("\nTienda 3")
print("Más vendido:", tienda3["Producto"].value_counts().idxmax())
print("Menos vendido:", tienda3["Producto"].value_counts().idxmin())

print("\nTienda 4")
print("Más vendido:", tienda4["Producto"].value_counts().idxmax())
print("Menos vendido:", tienda4["Producto"].value_counts().idxmin())
# Out:
# Productos más y menos vendidos:
#
# Tienda 1
# Más vendido: Microondas
# Menos vendido: Auriculares con micrófono
#
# Tienda 2
# Más vendido: Iniciando en programación
# Menos vendido: Juego de mesa
#
# Tienda 3
# Más vendido: Kit de bancas
# Menos vendido: Bloques de construcción
#
# Tienda 4
# Más vendido: Cama box
# Menos vendido: Guitarra eléctrica

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
print("Costo promedio de envío:\n")

print(f"Tienda 1: ${tienda1['Costo de envío'].mean():,.2f}")
print(f"Tienda 2: ${tienda2['Costo de envío'].mean():,.2f}")
print(f"Tienda 3: ${tienda3['Costo de envío'].mean():,.2f}")
print(f"Tienda 4: ${tienda4['Costo de envío'].mean():,.2f}")
# Out:
# Costo promedio de envío:
#
# Tienda 1: $26,018.61
# Tienda 2: $25,216.24
# Tienda 3: $24,805.68
# Tienda 4: $23,459.46

# %% [markdown]
# # 6. Gráfico

# %%
import matplotlib.pyplot as plt

def grafico_categorias(tienda, nombre_tienda):

    categorias = tienda["Categoría del Producto"].value_counts()

    plt.figure(figsize=(10,6))

    barras = plt.bar(
        categorias.index,
        categorias.values
    )

    plt.title(f"Ventas por Categoría - {nombre_tienda}", fontsize=16, fontweight="bold")
    plt.xlabel("Categoría", fontsize=12)
    plt.ylabel("Cantidad de Ventas", fontsize=12)

    plt.xticks(rotation=30)
    plt.grid(axis="y", linestyle="--", alpha=0.4)

    # Etiquetas de valor encima de cada barra
    for barra in barras:
        altura = barra.get_height()
        plt.text(
            barra.get_x() + barra.get_width()/2,
            altura,
            f"{int(altura):,}",
            ha="center",
            va="bottom",
            fontsize=10
        )

    plt.tight_layout()
    plt.show()


grafico_categorias(tienda1, "Tienda 1")
grafico_categorias(tienda2, "Tienda 2")
grafico_categorias(tienda3, "Tienda 3")
grafico_categorias(tienda4, "Tienda 4")

# %% [markdown]
# # 7. Extra

# %%
import matplotlib.pyplot as plt

def mapa_ventas(tienda, nombre):

    plt.figure(figsize=(8,6))

    plt.scatter(
        tienda["lon"],
        tienda["lat"],
        alpha=0.5
    )

    plt.title(f"Distribución geográfica de ventas - {nombre}", fontsize=14)
    plt.xlabel("Longitud")
    plt.ylabel("Latitud")

    plt.grid(alpha=0.3)

    plt.show()


mapa_ventas(tienda1, "Tienda 1")
mapa_ventas(tienda2, "Tienda 2")
mapa_ventas(tienda3, "Tienda 3")
mapa_ventas(tienda4, "Tienda 4")

# %%
import numpy as np
import matplotlib.pyplot as plt

def heatmap_ventas(tienda, nombre):

    plt.figure(figsize=(8,6))

    plt.hist2d(
        tienda["lon"],
        tienda["lat"],
        bins=40,
        cmap="Reds"
    )

    plt.colorbar(label="Cantidad de ventas")

    plt.title(f"Mapa de calor de ventas - {nombre}", fontsize=14)
    plt.xlabel("Longitud")
    plt.ylabel("Latitud")

    plt.show()


heatmap_ventas(tienda1, "Tienda 1")
heatmap_ventas(tienda2, "Tienda 2")
heatmap_ventas(tienda3, "Tienda 3")
heatmap_ventas(tienda4, "Tienda 4")

# %%
plt.figure(figsize=(10,7))

plt.scatter(tienda1["lon"], tienda1["lat"], alpha=0.4, label="Tienda 1")
plt.scatter(tienda2["lon"], tienda2["lat"], alpha=0.4, label="Tienda 2")
plt.scatter(tienda3["lon"], tienda3["lat"], alpha=0.4, label="Tienda 3")
plt.scatter(tienda4["lon"], tienda4["lat"], alpha=0.4, label="Tienda 4")

plt.title("Comparación geográfica de ventas entre tiendas", fontsize=15)
plt.xlabel("Longitud")
plt.ylabel("Latitud")

plt.legend()
plt.grid(alpha=0.3)

plt.show()

# %%
print("Ventas promedio por ubicación (Tienda 1)")
print(tienda1.groupby(["lat","lon"])["Precio"].sum().head())
# Out:
# Ventas promedio por ubicación (Tienda 1)
# lat       lon
# -4.21528  -69.94056     14669800.0
#  1.21361  -77.28111     14996400.0
#  2.92730  -75.28189      3494000.0
#  3.43722  -76.52250    154493700.0
#  3.86530  -67.92390      2722500.0
# Name: Precio, dtype: float64
